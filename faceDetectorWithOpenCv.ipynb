# %%
import cv2 as cv
import numpy as np
from cvzone.FaceDetectionModule import FaceDetector
from cvzone.FaceMeshModule import FaceMeshDetector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import cv2 as cv
#       2 import numpy as np
# ----> 3 from cvzone.FaceDetectionModule import FaceDetector
#       4 from cvzone.FaceMeshModule import FaceMeshDetector
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cvzone\FaceDetectionModule.py:8
#       1 """
#       2 Face Detection Module
#       3 By: Computer Vision Zone
#       4 Website: https://www.computervision.zone/
#       5 """
#       7 import cv2
# ----> 8 import mediapipe as mp
#      10 import cvzone
#      13 class FaceDetector:
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
cap = cv.VideoCapture(1)
detector = FaceDetector()
meshdetector = FaceMeshDetector(maxFaces=1)

while(True):
    rec, frame = cap.read()
    frame, bbox = detector.findFaces(frame)
    frame, faces = meshdetector.findFaceMesh(frame)

    if bbox:
        center = bbox[0]["center"]   
        #cv.circle(frame, center, 5, (255, 0, 255), cv.FILLED)
    cv.imshow('frame', frame)
    keyexit = cv.waitKey(5) & 0xFF
    if keyexit == 27:
        break

cv.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 cap = cv.VideoCapture(1)
# ----> 2 detector = FaceDetector()
#       3 meshdetector = FaceMeshDetector(maxFaces=1)
#       5 while(True):
#
# NameError: name 'FaceDetector' is not defined
