# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
original_img = cv.imread('E:\\New folder (6)\\Neuron_mid.jpg',0)

# %%
_, mask = cv.threshold(original_img, 25, 255, cv.THRESH_BINARY)

# %%
# Erosion
# kernel = np.ones((3,3), np.uint8)
# eroded_img = cv.erode(mask, kernel, iterations=1)

# %%
# Dilation
# kernel = np.ones((3,3), np.uint8)
# delated_img = cv.dilate(mask, kernel, iterations=1)
# kernel = np.ones((3,3), np.uint8)
# eroded_img = cv.erode(delated_img, kernel, iterations=1)

# %%
# Closing
# kernel = np.ones((3,3), np.uint8)
# closed_img = cv.morphologyEx(mask, cv.MORPH_CLOSE, kernel)

# %%
# Opening
# kernel1 = np.ones((4,4), np.uint8)
# kernel2 = np.ones((2,2), np.uint8)
# opened_img1 =cv.morphologyEx(mask, cv.MORPH_OPEN, kernel1)
# opened_img2 =cv.morphologyEx(mask, cv.MORPH_OPEN, kernel2)

# %%
# Gradient
kernel = np.ones((3,3), np.uint8)
gradient = cv.morphologyEx(mask, cv.MORPH_GRADIENT, kernel)
# delated_img = cv.dilate(mask, kernel, iterations=1)
# subtract_img = delated_img - mask

# %%
# cv.imshow('Original_img', original_img)
# cv.imshow('Mask', mask)
# cv.waitKey(0)
# cv.destroyAllWindows()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(10, 20))
cmap_val = 'gray'
ax1.axis("off")
ax1.title.set_text('')
ax2.axis("off")
ax2.title.set_text('')
ax3.axis("off")
ax3.title.set_text('')
ax1.imshow(mask, cmap=cmap_val)
ax2.imshow(opened_img1, cmap=cmap_val)
ax3.imshow(gradient, cmap=cmap_val)

plt.show()
