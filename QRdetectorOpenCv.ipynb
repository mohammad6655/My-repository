# %%
import cv2 as cv
import qrcode

# %%
# Generate QRcode
generated_qr_code = qrcode.make("Learn Python")
generated_qr_code.save('E:\\New folder (6)\\qrcode3.png')
generated_qr_code_cv = np.array(generated_qr_code)

# Detect QR code
qrcode_img = cv.imread('E:\\New folder (6)\\qrcode3.png')

detector = cv.QRCodeDetector()
value, box, _ = detector.detectAndDecode(qrcode_img)
print(value)
print(box)
# cv.rectangle(qrcode_img, (box[0][0][0], box[0][0][1]), (box[0][2][0], box[0][2][1]), (255,255,0), 2)

cv.imshow("barcode_img", qrcode_img)
cv.waitKey()
cv.destroyAllWindows()
# Out:
# Learn Python
# [[[ 40.  40.]
#   [249.  40.]
#   [249. 249.]
#   [ 40. 249.]]]
