# %%
import cv2 as cv
import numpy as np
from cvzone.FaceMeshModule import FaceMeshDetector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import cv2 as cv
#       2 import numpy as np
# ----> 3 from cvzone.FaceMeshModule import FaceMeshDetector
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cvzone\FaceMeshModule.py:8
#       1 """
#       2 Face Mesh Module
#       3 By: Computer Vision Zone
#       4 Website: https://www.computervision.zone/
#       5 """
#       7 import cv2
# ----> 8 import mediapipe as mp
#       9 import math
#      12 class FaceMeshDetector:
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
import cv2

# بارگذاری مدل‌های از پیش آموزش دیده Haar Cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# باز کردن وبکم
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # تشخیص صورت
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
        roi_gray = gray[y:y + h, x:x + w]
        roi_color = frame[y:y + h, x:x + w]

        # تشخیص چشم داخل صورت
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(roi_color, (ex, ey), (ex + ew, ey + eh), (0, 255, 0), 2)

    cv2.imshow('Eye Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.waitKey(0)
cv2.destroyAllWindows()
