# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('E:\web-258273318.jpg', cv.IMREAD_GRAYSCALE)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Mohammad\AppData\Local\Temp\ipykernel_8644\3545076473.py:1: SyntaxWarning: invalid escape sequence '\w'
#   img = cv.imread('E:\web-258273318.jpg', cv.IMREAD_GRAYSCALE)

# %%
#cv.IMREAD_GRAYSCALE 0
#cv.IMREAD_COLOR 1
#cv.IMREAF_UNCHANGED -1

# %%
cv.imshow('IMGE display', img)
cv.waitKey(5000)
cv.destroyAllWindows()

# %%
cv.imwrite("E:\\New folder (5)", img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 cv.imwrite("E:\\New folder (5)", img)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:1051: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'cv::imwrite_'
